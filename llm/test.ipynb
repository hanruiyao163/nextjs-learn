# %%
from PIL import Image, ImageDraw

# %%
image = Image.open("E:/huozai.jpg")
draw = ImageDraw.Draw(image)
draw.rectangle([0, 19, 476, 205], outline="red", width=1)

image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x266>

# %%
image = Image.open("E:/12.jpg")
draw = ImageDraw.Draw(image)
draw.rectangle([295, 456, 630, 671], outline="red", width=5)
draw.rectangle([818, 888, 1038, 1070], outline="red", width=5)

image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1080>
